# %% [markdown]
# # Portfolio DataScience Matthijs van Gastel - 2186230

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Assignment 1

# %% [markdown]
# ## Assignment 2

# %% [markdown]
# ## Assignment 3

# %% [markdown]
# Perform a univariate analysis on all the categorical data of the penguins dataset.

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins['sex'].value_counts(dropna=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Assignment 4

# %% [markdown]
# Look online for a datset that you personally find interesting to explore. It can be about any topic that you find interesting: sports, games, software development, etc.

# %%
gameData = pd.read_csv('Video_Games.csv', sep=',')
gameData.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# ## Assignment 5

# %% [markdown]
# - Download lifeExpectancyAtBirth.csv from Brightspace (original source).
# - Move the file to the same folder as the Notebook that you will be working in.
# - Load the dataset in your Notebook with the following code: lifeExpectancy = pd.read_csv('lifeExpectancyAtBirth.csv', sep=',')
# - Look at the dataset with the .head() function.
# - Filter the dataframe: We only want the life expectancy data about 2019 and 'Both sexes'
# - Use this dataframe to perform a univariate analysis on the life expectancy in 2019.
# - Which five countries have the highest life expectancy? Which five the lowest?

# %%
lifeExpectancy = pd.read_csv('lifeExpectancyAtBirth.csv', sep=',')
lifeExpectancy.head()
# Out:
#       Location  Period                         Indicator        Dim1  \
# 0  Afghanistan    2019  Life expectancy at birth (years)  Both sexes
# 1  Afghanistan    2019  Life expectancy at birth (years)        Male
# 2  Afghanistan    2019  Life expectancy at birth (years)      Female
# 3  Afghanistan    2015  Life expectancy at birth (years)  Both sexes
# 4  Afghanistan    2015  Life expectancy at birth (years)        Male
#
#    First Tooltip
# 0          63.21
# 1          63.29
# 2          63.16
# 3          61.65
# 4          61.04

# %%
lifeExpectancyFilter = (lifeExpectancy['Period'] == 2019)&(lifeExpectancy['Dim1']=='Both sexes')
lifeExpectancy[lifeExpectancyFilter]
# Out:
#                                 Location  Period  \
# 0                            Afghanistan    2019
# 12                               Albania    2019
# 24                               Algeria    2019
# 36                                Angola    2019
# 48                   Antigua and Barbuda    2019
# ...                                  ...     ...
# 2137  Venezuela (Bolivarian Republic of)    2019
# 2149                            Viet Nam    2019
# 2161                               Yemen    2019
# 2173                              Zambia    2019
# 2185                            Zimbabwe    2019
#
#                              Indicator        Dim1  First Tooltip
# 0     Life expectancy at birth (years)  Both sexes          63.21
# 12    Life expectancy at birth (years)  Both sexes          78.00
# 24    Life expectancy at birth (years)  Both sexes          77.13
# 36    Life expectancy at birth (years)  Both sexes          63.06
# 48    Life expectancy at birth (years)  Both sexes          76.45
# ...                                ...         ...            ...
# 2137  Life expectancy at birth (years)  Both sexes          73.95
# 2149  Life expectancy at birth (years)  Both sexes          73.74
# 2161  Life expectancy at birth (years)  Both sexes          66.63
# 2173  Life expectancy at birth (years)  Both sexes          62.45
# 2185  Life expectancy at birth (years)  Both sexes          60.68
#
# [183 rows x 5 columns]

# %%
life= lifeExpectancy[lifeExpectancyFilter]
life['First Tooltip'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
life['First Tooltip'].describe()
# Out:
# count    183.000000
# mean      72.540492
# std        7.129956
# min       50.750000
# 25%       66.550000
# 50%       73.740000
# 75%       77.730000
# max       84.260000
# Name: First Tooltip, dtype: float64

# %%
lifeExpectancy[lifeExpectancyFilter].sort_values(by='First Tooltip')
# Out:
#                       Location  Period                         Indicator  \
# 1117                   Lesotho    2019  Life expectancy at birth (years)
# 373   Central African Republic    2019  Life expectancy at birth (years)
# 1801                   Somalia    2019  Life expectancy at birth (years)
# 661                   Eswatini    2019  Life expectancy at birth (years)
# 1333                Mozambique    2019  Life expectancy at birth (years)
# ...                        ...     ...                               ...
# 1837                     Spain    2019  Life expectancy at birth (years)
# 1753                 Singapore    2019  Life expectancy at birth (years)
# 1573         Republic of Korea    2019  Life expectancy at birth (years)
# 1897               Switzerland    2019  Life expectancy at birth (years)
# 997                      Japan    2019  Life expectancy at birth (years)
#
#             Dim1  First Tooltip
# 1117  Both sexes          50.75
# 373   Both sexes          53.10
# 1801  Both sexes          56.47
# 661   Both sexes          57.73
# 1333  Both sexes          58.14
# ...          ...            ...
# 1837  Both sexes          83.22
# 1753  Both sexes          83.22
# 1573  Both sexes          83.30
# 1897  Both sexes          83.45
# 997   Both sexes          84.26
#
# [183 rows x 5 columns]

# %% [markdown]
#       Hoogste                          Laagste
#     1. Lesotho                      1. Japan
#     2. Central African Republic     2. Switzerland
#     3. Somalia                      3. Republic of Korea
#     4. Eswatini                     4. Singapore
#     5. MozamBique                   5. Spain

# %% [markdown]
# ## Assignment 6

# %% [markdown]
# Perform a univariate analysis on at least 2 columns with categorical data and on at least 2 columns with numerical data in the dataset that you chose in portfolio assignment 4.

# %%
gameData.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
gameData['Genre'].value_counts(dropna=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
gameData['Platform'].value_counts(dropna=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
gameData['Year_of_Release'].value_counts(dropna=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
gameData['Rating'].value_counts(dropna=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Assignment 7

# %% [markdown]
# Look at the histogram of at least 2 columns with numerical data in the dataset that you chose in portfolio assignment 4. Do you recognise the distribution? Does it look like a uniform or normal distribution or something else? If it doesn't look like a uniform or normal distribution, take a quick look here to see if you can find the distribution shape: https://www.itl.nist.gov/div898/handbook/eda/section3/eda366.htm

# %%
gameData['Year_of_Release'].plot(kind='hist', bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
gameData['Critic_Score'].plot(kind='hist', bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# De verdeling(distrubution) heeft de vorm van een Extreme Value Type I Distribution, dit is bij beide histogrammen het geval

# %% [markdown]
# ## Assignment 8

# %% [markdown]
# - Calculate the 90%, 95%, 99% and 99.99% confidence interval for at least 2 columns with numerical data in the dataset that you chose in portfolio assignment 4. Do you see the impact the confidence has on the interval?
# - Now calculate the 95% confidence interval again but use only the first 10% of your rows. Compare this interval to the previous 95% confidence interval you calculated. Do you see the impact of having less data?

# %%
import scipy.stats as st
confidence = 0.90
st.t.interval(confidence, len(gameData)-1, loc=gameData['Global_Sales'].mean(), scale=st.sem(gameData['Global_Sales']))
# Out:
# (0.5138502632906128, 0.553235088704279)

# %%
confidence = 0.95
st.t.interval(confidence, len(gameData)-1, loc=gameData['Global_Sales'].mean(), scale=st.sem(gameData['Global_Sales']))
# Out:
# (0.5100773203574843, 0.5570080316374074)

# %%
confidence = 0.99
st.t.interval(confidence, len(gameData)-1, loc=gameData['Global_Sales'].mean(), scale=st.sem(gameData['Global_Sales']))
# Out:
# (0.502702682880596, 0.5643826691142957)

# %%
confidence = 0.9999
st.t.interval(confidence, len(gameData)-1, loc=gameData['Global_Sales'].mean(), scale=st.sem(gameData['Global_Sales']))
# Out:
# (0.4869553170050783, 0.5801300349898134)

# %%
confidence = 0.95
st.t.interval(confidence, len(gameData)-1, loc=gameData['Global_Sales'].mean(), scale=st.sem(gameData['Global_Sales']*0.1))
# Out:
# (0.5311961404334498, 0.535889211561442)

# %%
confidence = 0.90
st.t.interval(confidence, len(gameData)-1, loc=gameData['EU_Sales'].mean(), scale=st.sem(gameData['EU_Sales']))
# Out:
# (0.13862218785473504, 0.1514274562628017)

# %%
confidence = 0.95
st.t.interval(confidence, len(gameData)-1, loc=gameData['EU_Sales'].mean(), scale=st.sem(gameData['EU_Sales']))
# Out:
# (0.1373954832435153, 0.15265416087402145)

# %%
confidence = 0.99
st.t.interval(confidence, len(gameData)-1, loc=gameData['EU_Sales'].mean(), scale=st.sem(gameData['EU_Sales']))
# Out:
# (0.13499775235828523, 0.15505189175925152)

# %%
confidence = 0.9999
st.t.interval(confidence, len(gameData)-1, loc=gameData['EU_Sales'].mean(), scale=st.sem(gameData['EU_Sales']))
# Out:
# (0.1298777792560035, 0.16017186486153326)

# %%
confidence = 0.95
st.t.interval(confidence, len(gameData)-1, loc=gameData['EU_Sales'].mean(), scale=st.sem(gameData['EU_Sales']*0.1))
# Out:
# (0.14426188817724306, 0.1457877559402937)

# %% [markdown]
# ## Assignment 9

# %% [markdown]
# Perform a bivariate analysis on the columns with numerical data in the penguins dataset.
#
# Use corr() on the DataFrame to calculate all the correlations. (Use the code example above to) show the correlation table with colors.
# Look at the corrrelations. Do they match your expectations?
# - Show a scatter plot for
#  - The strongest positive correlation
#  - The strongest negative correlation
#  - The weakest correlation

# %%
penguins = sns.load_dataset("penguins")
penguinDataCorrelations = penguins.corr()
penguinDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_6a576_row0_col0, #T_6a576_row1_col1, #T_6a576_row2_col2, #T_6a576_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6a576_row0_col1, #T_6a576_row1_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_6a576_row0_col2, #T_6a576_row2_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_6a576_row0_col3, #T_6a576_row3_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_6a576_row1_col2, #T_6a576_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6a576_row1_col3, #T_6a576_row3_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6a576_row2_col3, #T_6a576_row3_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a576">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a576_level0_col0" class="col_heading level0 col0" >bill_length_mm</th>
#       <th id="T_6a576_level0_col1" class="col_heading level0 col1" >bill_depth_mm</th>
#       <th id="T_6a576_level0_col2" class="col_heading level0 col2" >flipper_length_mm</th>
#       <th id="T_6a576_level0_col3" class="col_heading level0 col3" >body_mass_g</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a576_level0_row0" class="row_heading level0 row0" >bill_length_mm</th>
#       <td id="T_6a576_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_6a576_row0_col1" class="data row0 col1" >-0.24</td>
#       <td id="T_6a576_row0_col2" class="data row0 col2" >0.66</td>
#       <td id="T_6a576_row0_col3" class="data row0 col3" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_6a576_level0_row1" class="row_heading level0 row1" >bill_depth_mm</th>
#       <td id="T_6a576_row1_col0" class="data row1 col0" >-0.24</td>
#       <td id="T_6a576_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_6a576_row1_col2" class="data row1 col2" >-0.58</td>
#       <td id="T_6a576_row1_col3" class="data row1 col3" >-0.47</td>
#     </tr>
#     <tr>
#       <th id="T_6a576_level0_row2" class="row_heading level0 row2" >flipper_length_mm</th>
#       <td id="T_6a576_row2_col0" class="data row2 col0" >0.66</td>
#       <td id="T_6a576_row2_col1" class="data row2 col1" >-0.58</td>
#       <td id="T_6a576_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_6a576_row2_col3" class="data row2 col3" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_6a576_level0_row3" class="row_heading level0 row3" >body_mass_g</th>
#       <td id="T_6a576_row3_col0" class="data row3 col0" >0.60</td>
#       <td id="T_6a576_row3_col1" class="data row3 col1" >-0.47</td>
#       <td id="T_6a576_row3_col2" class="data row3 col2" >0.87</td>
#       <td id="T_6a576_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
penguins.plot(kind='scatter', x='flipper_length_mm', y='body_mass_g')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
penguins.plot(kind='scatter', x='bill_depth_mm', y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='flipper_length_mm'>

# %%
penguins.plot(kind='scatter', x='bill_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# ## Assignment 10

# %% [markdown]
# Perform a bivariate analysis (Pearson correlation and scatter plot) on at least 1 combination of 2 columns with numeric data in the dataset that you chose in portfolio assignment 4. Does the correlation and scatter plot match your expectations? Add your answer to your notebook. Commit the Notebook to your portfolio when you're finished.

# %%
gameDataCorrelations = gameData.corr()
gameDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_6a9b1_row0_col0, #T_6a9b1_row1_col1, #T_6a9b1_row2_col2, #T_6a9b1_row3_col3, #T_6a9b1_row4_col4, #T_6a9b1_row5_col5, #T_6a9b1_row6_col6, #T_6a9b1_row7_col7, #T_6a9b1_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6a9b1_row0_col1, #T_6a9b1_row1_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_6a9b1_row0_col2, #T_6a9b1_row2_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6a9b1_row0_col3, #T_6a9b1_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6a9b1_row0_col4, #T_6a9b1_row4_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6a9b1_row0_col5, #T_6a9b1_row5_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_6a9b1_row0_col6, #T_6a9b1_row6_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6a9b1_row0_col7, #T_6a9b1_row2_col6, #T_6a9b1_row6_col2, #T_6a9b1_row7_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_6a9b1_row0_col8, #T_6a9b1_row8_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_6a9b1_row1_col2, #T_6a9b1_row2_col1 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_6a9b1_row1_col3, #T_6a9b1_row3_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_6a9b1_row1_col4, #T_6a9b1_row4_col1 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_6a9b1_row1_col5, #T_6a9b1_row5_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_6a9b1_row1_col6, #T_6a9b1_row4_col8, #T_6a9b1_row6_col1, #T_6a9b1_row8_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6a9b1_row1_col7, #T_6a9b1_row7_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_6a9b1_row1_col8, #T_6a9b1_row5_col6, #T_6a9b1_row6_col5, #T_6a9b1_row8_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_6a9b1_row2_col3, #T_6a9b1_row3_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_6a9b1_row2_col4, #T_6a9b1_row4_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_6a9b1_row2_col5, #T_6a9b1_row5_col2 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_6a9b1_row2_col7, #T_6a9b1_row7_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_6a9b1_row2_col8, #T_6a9b1_row8_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_6a9b1_row3_col4, #T_6a9b1_row4_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_6a9b1_row3_col5, #T_6a9b1_row5_col3 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_6a9b1_row3_col6, #T_6a9b1_row6_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_6a9b1_row3_col7, #T_6a9b1_row7_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_6a9b1_row3_col8, #T_6a9b1_row8_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_6a9b1_row4_col5, #T_6a9b1_row5_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_6a9b1_row4_col6, #T_6a9b1_row6_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_6a9b1_row4_col7, #T_6a9b1_row7_col4 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_6a9b1_row5_col7, #T_6a9b1_row7_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_6a9b1_row5_col8, #T_6a9b1_row6_col8, #T_6a9b1_row8_col5, #T_6a9b1_row8_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_6a9b1_row6_col7, #T_6a9b1_row7_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_6a9b1_row7_col8, #T_6a9b1_row8_col7 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# </style>
# <table id="T_6a9b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a9b1_level0_col0" class="col_heading level0 col0" >Year_of_Release</th>
#       <th id="T_6a9b1_level0_col1" class="col_heading level0 col1" >NA_Sales</th>
#       <th id="T_6a9b1_level0_col2" class="col_heading level0 col2" >EU_Sales</th>
#       <th id="T_6a9b1_level0_col3" class="col_heading level0 col3" >JP_Sales</th>
#       <th id="T_6a9b1_level0_col4" class="col_heading level0 col4" >Other_Sales</th>
#       <th id="T_6a9b1_level0_col5" class="col_heading level0 col5" >Global_Sales</th>
#       <th id="T_6a9b1_level0_col6" class="col_heading level0 col6" >Critic_Score</th>
#       <th id="T_6a9b1_level0_col7" class="col_heading level0 col7" >Critic_Count</th>
#       <th id="T_6a9b1_level0_col8" class="col_heading level0 col8" >User_Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a9b1_level0_row0" class="row_heading level0 row0" >Year_of_Release</th>
#       <td id="T_6a9b1_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_6a9b1_row0_col1" class="data row0 col1" >-0.09</td>
#       <td id="T_6a9b1_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_6a9b1_row0_col3" class="data row0 col3" >-0.17</td>
#       <td id="T_6a9b1_row0_col4" class="data row0 col4" >0.04</td>
#       <td id="T_6a9b1_row0_col5" class="data row0 col5" >-0.08</td>
#       <td id="T_6a9b1_row0_col6" class="data row0 col6" >0.01</td>
#       <td id="T_6a9b1_row0_col7" class="data row0 col7" >0.22</td>
#       <td id="T_6a9b1_row0_col8" class="data row0 col8" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_6a9b1_level0_row1" class="row_heading level0 row1" >NA_Sales</th>
#       <td id="T_6a9b1_row1_col0" class="data row1 col0" >-0.09</td>
#       <td id="T_6a9b1_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_6a9b1_row1_col2" class="data row1 col2" >0.77</td>
#       <td id="T_6a9b1_row1_col3" class="data row1 col3" >0.45</td>
#       <td id="T_6a9b1_row1_col4" class="data row1 col4" >0.64</td>
#       <td id="T_6a9b1_row1_col5" class="data row1 col5" >0.94</td>
#       <td id="T_6a9b1_row1_col6" class="data row1 col6" >0.24</td>
#       <td id="T_6a9b1_row1_col7" class="data row1 col7" >0.30</td>
#       <td id="T_6a9b1_row1_col8" class="data row1 col8" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_6a9b1_level0_row2" class="row_heading level0 row2" >EU_Sales</th>
#       <td id="T_6a9b1_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_6a9b1_row2_col1" class="data row2 col1" >0.77</td>
#       <td id="T_6a9b1_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_6a9b1_row2_col3" class="data row2 col3" >0.44</td>
#       <td id="T_6a9b1_row2_col4" class="data row2 col4" >0.72</td>
#       <td id="T_6a9b1_row2_col5" class="data row2 col5" >0.90</td>
#       <td id="T_6a9b1_row2_col6" class="data row2 col6" >0.22</td>
#       <td id="T_6a9b1_row2_col7" class="data row2 col7" >0.28</td>
#       <td id="T_6a9b1_row2_col8" class="data row2 col8" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_6a9b1_level0_row3" class="row_heading level0 row3" >JP_Sales</th>
#       <td id="T_6a9b1_row3_col0" class="data row3 col0" >-0.17</td>
#       <td id="T_6a9b1_row3_col1" class="data row3 col1" >0.45</td>
#       <td id="T_6a9b1_row3_col2" class="data row3 col2" >0.44</td>
#       <td id="T_6a9b1_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_6a9b1_row3_col4" class="data row3 col4" >0.29</td>
#       <td id="T_6a9b1_row3_col5" class="data row3 col5" >0.61</td>
#       <td id="T_6a9b1_row3_col6" class="data row3 col6" >0.15</td>
#       <td id="T_6a9b1_row3_col7" class="data row3 col7" >0.18</td>
#       <td id="T_6a9b1_row3_col8" class="data row3 col8" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_6a9b1_level0_row4" class="row_heading level0 row4" >Other_Sales</th>
#       <td id="T_6a9b1_row4_col0" class="data row4 col0" >0.04</td>
#       <td id="T_6a9b1_row4_col1" class="data row4 col1" >0.64</td>
#       <td id="T_6a9b1_row4_col2" class="data row4 col2" >0.72</td>
#       <td id="T_6a9b1_row4_col3" class="data row4 col3" >0.29</td>
#       <td id="T_6a9b1_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_6a9b1_row4_col5" class="data row4 col5" >0.75</td>
#       <td id="T_6a9b1_row4_col6" class="data row4 col6" >0.20</td>
#       <td id="T_6a9b1_row4_col7" class="data row4 col7" >0.25</td>
#       <td id="T_6a9b1_row4_col8" class="data row4 col8" >0.24</td>
#     </tr>
#     <tr>
#       <th id="T_6a9b1_level0_row5" class="row_heading level0 row5" >Global_Sales</th>
#       <td id="T_6a9b1_row5_col0" class="data row5 col0" >-0.08</td>
#       <td id="T_6a9b1_row5_col1" class="data row5 col1" >0.94</td>
#       <td id="T_6a9b1_row5_col2" class="data row5 col2"

# %%
gameData.plot(kind='scatter', x='NA_Sales', y='Global_Sales')
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='Global_Sales'>

# %%
gameData.plot(kind='scatter', x='User_Count', y='JP_Sales')
# Out:
# <AxesSubplot:xlabel='User_Count', ylabel='JP_Sales'>

# %%
gameData.plot(kind='scatter', x='Year_of_Release', y='EU_Sales')
# Out:
# <AxesSubplot:xlabel='Year_of_Release', ylabel='EU_Sales'>

# %% [markdown]
# De correlaties zijn wel te verwachten. want bijvoorbeeld NA maakt en de EU  maken een groot deel uit va de wereld. dus tussen NA en Global sales en ook EU en Global was een hoge correlatie te verwachten. ook was te verwachten dat als je een scatterplot maakt en op de x-as of y-as Year_of_Release gebruikt samen met een van de sales dat het eerder een barplot is dan een scatterplot, want er wordt eigenlijk gekeken naar aantal sales per jaar

# %% [markdown]
# ## Assignment 11

# %% [markdown]
# Do a Numerical VS Categorical bivariate analysis on the penguins dataset.
#
# - Choose one of the categorical columns: species, island or sex
# - use .groupby('').mean() too look at the means of the numerical columns. Does it look like there is a difference between categories?
# - Use the seaborn barplot to plot the mean and confidence. Create this plot for each of the numerical columns (bill_length_mm bill_depth_mm, flipper_length_mm, body_mass_g)
# - For each of the plots, write a conclusion: Is there a statistically significant difference for this numerical column for each category?

# %%
penguins.groupby('island').mean()
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# island
# Biscoe          45.257485      15.874850         209.706587  4716.017964
# Dream           44.167742      18.344355         193.072581  3712.903226
# Torgersen       38.950980      18.429412         191.196078  3706.372549

# %%
sns.barplot(y="bill_length_mm", x="island", data=penguins)
# Out:
# <AxesSubplot:xlabel='island', ylabel='bill_length_mm'>

# %% [markdown]
# er is weinig verschil tussen de bill_length_mm, behalve bij  Torgersen vergeleken met de andere. maar nog steeds een klein verschil

# %%
sns.barplot(y="bill_depth_mm", x="island", data=penguins)
# Out:
# <AxesSubplot:xlabel='island', ylabel='bill_depth_mm'>

# %% [markdown]
# hier is Biscoe island lager, maar het verschil is niet enorm

# %%
sns.barplot(y="flipper_length_mm", x="island", data=penguins)
# Out:
# <AxesSubplot:xlabel='island', ylabel='flipper_length_mm'>

# %% [markdown]
# hier valt op dat biscoe island groter is dan de andere 2, maar relatief gezien is dit niet veel

# %%
sns.barplot(y="body_mass_g", x="island", data=penguins)
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %% [markdown]
# hier valt op dat biscoe island een stuk hoger is dan de andere twee, ook relatief gezien zit er toch nog een redelelijk verschil

# %% [markdown]
# ## Assignment 12

# %% [markdown]
# Perform a bivariate analysis on at least 3 combinations of a numerical column with a categorical column in the dataset that you chose in portfolio assignment 4. Use .groupby('columnname').mean() to calculate the means. Is there a difference between categories? Then use seaborn barplots to check if there is a statistically significant difference.

# %%
gameData.groupby("Genre").mean()
# Out:
#               Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action            2008.050181  0.260834  0.154045  0.047905     0.054777
# Adventure         2008.263728  0.080783  0.048764  0.040138     0.012655
# Fighting          2004.653524  0.263086  0.118174  0.103039     0.042827
# Misc              2007.328298  0.232726  0.121566  0.061777     0.042509
# Platform          2003.857631  0.501689  0.225619  0.147331     0.057534
# Puzzle            2005.230228  0.211845  0.086224  0.098810     0.021345
# Racing            2004.864600  0.287710  0.189359  0.045404     0.060929
# Role-Playing      2007.130816  0.220540  0.125807  0.236973     0.039753
# Shooter           2006.033179  0.447649  0.239864  0.029297     0.078692
# Simulation        2006.663170  0.208455  0.129886  0.072998     0.035183
# Sports            2005.503036  0.291495  0.160473  0.057726     0.057287
# Strategy          2005.618128  0.100366  0.066135  0.072709     0.015886
#
#               Global_Sales  Critic_Score  Critic_Count  User_Count
# Genre
# Action            0.517884     66.629101     27.780952  188.889617
# Adventure         0.182417     65.331269     22.114551  103.410000
# Fighting          0.527067     69.217604     27.909535   64.929825
# Misc              0.458960     66.619503     21.533461   31.113895
# Platform          0.932523     68.058350     23.698189  109.128505
# Puzzle            0.419000     67.424107     20.308036   32.500000
# Racing            0.583587     67.963612     23.028302   69.372855
# Role-Playing      0.622933     72.652646     32.489824  320.746972
# Shooter           0.795873     70.181144     35.610169  374.577922
# Simulation        0.446705     68.619318     21.446023   82.656977
# Sports            0.567291     71.968174     21.030151   41.567543
# Strategy          0.255490     72.086093     28.271523  196.221865

# %%
plot = sns.barplot(y="Global_Sales", x="Genre", data=gameData)
for item in plot.get_xticklabels():
    item.set_rotation(90)

# %%
plot = sns.barplot(y="User_Count", x="Genre", data=gameData)
for item in plot.get_xticklabels():
    item.set_rotation(90)

# %%
plot = sns.barplot(y="Critic_Score", x="Genre", data=gameData)
for item in plot.get_xticklabels():
    item.set_rotation(90)

# %% [markdown]
# er zijn duidelijk wat verschillen in de categoriën, bij Critc_Score valt dit verschil wel mee, alles zit rond de 70. Bij Global_Sales zijn shooter en platform duidelijke uitschieters. Bij User_Count is dit Role-Playing en Shooter

# %% [markdown]
# ## Assignment 13

# %% [markdown]
# Do a bivariate analysis on the penguins dataset for the following combination of columns:
#
# - species VS sex
# - island VS sex
#
# For this bivariate analysis, at least perform the following tasks:
#
# - Do you expect their to be a correlation between the two columns?
# - Create a contingency table. Do you observe different ratios between categories here?
# - Create a bar plot for this contingency table. Do you observe different ratios between categories here?
# - Do a chi-squared test. What does the result say? What's the chance of there being a correlation between the two columns?
